# %% [markdown]
# <a href="https://colab.research.google.com/github/Mannshah2732/datascience_assignment/blob/main/Module4_Regression_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is Simple Linear Regression.
#
# * Simple Linear Regression is a statistical method used to model the relationship between two variables:
#
#   * One independent variable (X) — also called the predictor or feature.
#
#   * One dependent variable (y) — also called the response or target.
#
#   * Mathematical Formula : y=β0 + β1x + ε
#
#     Where :
#
#       𝑦 = dependent variable (what you want to predict)
#
#       𝑥 = independent variable
#
#       𝛽0 = intercept (value of 𝑦 when 𝑥 = 0)
#
#       𝛽1  = slope (change in 𝑦 for a one-unit change in 𝑥)
#
#       𝜀 = error term (difference between actual and predicted values)

# %% [markdown]
# 2. What are the key assumptions of Simple Linear Regression.
#
# * Simple Linear Regression (SLR) relies on several key assumptions to ensure the model produces valid, reliable, and interpretable results.
#
# * Here are the five main assumptions:
#
# 1.  Linearity
#
#   * Assumption: The relationship between the independent variable 𝑋 and the dependent variable 𝑦 is linear.
#
# 2. Independence of Errors (No Autocorrelation)
#
#   * Assumption: The residuals (errors) are independent of each other.
#
# 3. Homoscedasticity (Constant Variance of Errors)
#
#   * Assumption: The residuals have constant variance at every level of 𝑋.
#
# 4. Normality of Errors
#
#   * Assumption: The residuals (errors) are normally distributed.
#
# 5. No Perfect Multicollinearity (not relevant in simple linear regression)
#
#   * This assumption is important in multiple linear regression when you have more than one independent variable.

# %% [markdown]
# 3. What does the coefficient m represent in the equation Y=mX+c
#
# In the linear equation : Y=mX+c
#
# The coefficient m represents the slope of the line.
#
# * It indicates the rate of change of the dependent variable Y with respect to the independent variable X.
#
# * In simple terms, it shows how much Y increases or decreases when X increases by 1 unit.
#
# * Interpretation Example :
#
#   If : Y=2X+5
#
#   Then :
#
#      * m=2 → For every 1 unit increase in X, the value of Y increases by 2 units.
#
#      * c=5 → This is the intercept; the value of Y when X=0.

# %% [markdown]
# 4.  What does the intercept c represent in the equation Y=mX+c
#
# In the linear equation : Y=mX+c
#
# The term c represents the intercept, also known as the Y-intercept.
#
# * It is the value of Y when the independent variable X=0.
#
# * In other words, it's the point where the line crosses the Y-axis on a graph.
#
# * Interpretation Example :
#
#   If : Y=3X+7
#
#   Then :
#
#     * c=7 → When X=0, Y=7.
#
#     * This means if you plug in X=0, the output Y will be 7, regardless of the slope.

# %% [markdown]
# 5.  How do we calculate the slope m in Simple Linear Regression
#
# * In Simple Linear Regression, the slope m (often denoted as β1) represents the rate of change in the dependent variable y for each unit change in the independent variable x.
#
# * Formula to Calculate the Slope 𝑚 :
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
# * 𝑥𝑖, 𝑦𝑖 are the individual data points.
#
# * 𝑥ˉ = mean of 𝑥
#
# * 𝑦ˉ = mean of 𝑦

# %% [markdown]
# 6.  What is the purpose of the least squares method in Simple Linear Regression
#
# * The purpose of the Least Squares Method in Simple Linear Regression is to find the best-fitting line through a set of data points by minimizing the total error between the predicted values and the actual values.
#
# * Key Objective :
#
#   * To minimize the sum of squared residuals — also known as the Sum of Squared Errors (SSE).
#
#   ![image.png](data:image/png;base64,...)
#
#   Where:
#
#     * 𝑦𝑖 = actual value
#
#     * 𝑦^𝑖 =𝑚𝑥𝑖 + 𝑐 = predicted value
#
#     * (𝑦𝑖 − 𝑦^𝑖) = residual (error for each point)
#
# The Least Squares Method is used to :
#
# * Determine the most accurate linear equation
#
# * Quantify and reduce prediction error
#
# * Ensure the model generalizes well to unseen data

# %% [markdown]
# 7.  How is the coefficient of determination (R²) interpreted in Simple Linear Regression
#
# * In Simple Linear Regression, the coefficient of determination, denoted as 𝑅2, measures how well the regression line explains the variation in the dependent variable 𝑦.
#
# * Definition of 𝑅2 :
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
# SSres = Sum of squared residuals (errors)
#
# SStot = Total sum of squares (total variance in 𝑦)
#
# *  Example :
#
#   If you're predicting house prices based on square footage:
#
#   𝑅2 = 0.90 → 90% of the variation in house prices is explained by square footage.

# %% [markdown]
# 8.  What is Multiple Linear Regression
#
# * Multiple Linear Regression (MLR) is an extension of Simple Linear Regression that models the relationship between one dependent variable and two or more independent variables.
#
# * Definition :
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
#   * 𝑌 = dependent (target) variable
#
#   * 𝑋1, 𝑋2,… ,𝑋𝑛 = independent (predictor) variables
#
#   * 𝛽0 = intercept
#
#   * 𝛽1, 𝛽2, … , 𝛽𝑛 = coefficients (slopes) for each 𝑋
#
#   * 𝜀 = error term
#
# * Purpose of MLR :
#
#   To predict the value of 𝑌 using multiple features, and to understand how each feature influences the outcome while controlling for others.
#
# *  Example :
#
#   Suppose you're predicting a person's salary based on :
#
#   Education level (𝑋1)
#
#   Years of experience (𝑋2)
#
#   Age (𝑋3)
#
#   Then the equation might look like :
#
#   Salary = β0 + β1(Education) + β2(Experience) + β3(Age) + ε
#
# * When to Use Multiple Linear Regression :
#
#   * When the outcome depends on more than one factor.
#
#   * When you want to control for other variables to isolate the effect of one.

# %% [markdown]
# 9. What is the main difference between Simple and Multiple Linear Regression
#
# * The main difference between Simple Linear Regression (SLR) and Multiple Linear Regression (MLR) lies in the number of independent (predictor) variables used to predict the dependent (target) variable.
#
# * Example :
#
#   * SLR : Predict house price using only square footage
#
#     * Price = 𝛽0 + 𝛽1(SqFt) + 𝜀
#
#   * MLR : Predict house price using square footage, number of bedrooms, and location
#
#     * Price = 𝛽0 + 𝛽1(SqFt) + 𝛽2(Bedrooms) + 𝛽3(Location) + 𝜀
#
# * Summary :
# * Use Simple Linear Regression when there is one predictor.
#
# * Use Multiple Linear Regression when you have two or more predictors and want a more comprehensive model.

# %% [markdown]
# 10. What are the key assumptions of Multiple Linear Regression
#
# * Multiple Linear Regression (MLR) has several key assumptions that must be met to ensure the model is valid, interpretable, and produces reliable results.
#
# Key Assumptions of Multiple Linear Regression :
#
# 1. Linearity
#
#     * The relationship between each independent variable and the dependent variable is linear.
#     * Scatter plots or partial regression plots.
#
# 2. Independence of Errors (No Autocorrelation)
#
#     * The residuals (errors) should be independent of each other.
#     * Especially critical in time-series data.
#     * Durbin-Watson test.
#
# 3.  Homoscedasticity (Constant Variance of Errors)
#
#     * The variance of the residuals is constant across all levels of the independent variables.
#     * Plot residuals vs. predicted values.
#
# 4. No Multicollinearity
#
#     * Independent variables should not be highly correlated with each other.
#     * High correlation distorts the estimation of coefficients.
#     * Variance Inflation Factor (VIF) — VIF > 5 or 10 is problematic.

# %% [markdown]
# 11.  What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model
#
# * Heteroscedasticity occurs when the variance of the residuals (errors) in a regression model is not constant across all levels of the independent variables.
#
# * In Simple Terms :
#
#   In a well-behaved regression model, the spread of residuals should be roughly the same regardless of the value of the predictors — this is called homoscedasticity.
#
#   When the spread changes (e.g., gets wider or narrower as 𝑋 increases), we have heteroscedasticity.
#
# * Example :
#
#   In a residuals vs. predicted values plot:
#
#   Homoscedasticity: Residuals look like a horizontal cloud (equal spread).
#
#   Heteroscedasticity: Residuals fan out or funnel in (triangle or cone shape).
#
# * How Heteroscedasticity Affects the Model :
#
#   1. Incorrect Standard Errors
#
#    * Biased confidence intervals
#    * Misleading p-values
#    * Potentially wrong conclusions about statistical significance
#
#   2. Coefficient Estimates Remain Unbiased
#
#    * They may still be correct "on average"
#    * But they're less precise
#
#   3. Over- or underestimating predictive power
#
#    * The model may seem better (or worse) than it actually is for certain values of predictors.

# %% [markdown]
# 12.  How can you improve a Multiple Linear Regression model with high multicollinearity
#
# * If your Multiple Linear Regression model has high multicollinearity, it means some of your independent variables are highly correlated with each other.
# * This makes it difficult to estimate the effect of each variable accurately.
#
# * How to Improve the Model :
#
# 1. Remove One of the Correlated Variables
#
#   If two variables are highly correlated (e.g., height and arm span), consider dropping one.
#
#   Example :
#
#   # Check VIF and drop variables with high VIF
#
# 2. Combine Correlated Variables
#
#   Use feature engineering to combine correlated variables into a single one.
#
#   Example :
#
#   Combine height and weight into BMI
#
# 3. Principal Component Analysis (PCA)
#
#   Transform correlated variables into a smaller set of uncorrelated components.
#
#   Pro: Removes multicollinearity
#
#   Con: Harder to interpret results
#
# 4. Use Regularization Techniques
#
#   Regularization methods shrink or eliminate problematic coefficients :
#
#     * Ridge Regression (L2)
#
#       * Reduces coefficient magnitudes but keeps all variables
#
#     * Lasso Regression (L1)
#
#       * Can shrink some coefficients to exactly zero (feature selection)
#
#     * Elastic Net
#
#       * Combines Ridge and Lasso
#
# 5. Collect More Data
#
#   Sometimes, multicollinearity arises from small sample sizes. More data can reduce it.

# %% [markdown]
# 13. What are some common techniques for transforming categorical variables for use in regression models
#
# * Transforming categorical variables into a numerical format is essential before using them in regression models, which require numerical inputs.
#
# Here are the most common techniques :
#
# 1. One-Hot Encoding (Dummy Variables)
#
# * Converts each category into a separate binary column (0 or 1).
#
# * Commonly used for nominal (unordered) categories.
#
# 2. Label Encoding
#
# * Assigns each category a unique number.
#
# * Best for ordinal variables where order matters (e.g., Low, Medium, High).
#
# 3. Ordinal Encoding (Custom Mapping)
#
# * Map categories to numbers based on meaningful order.
#
# 4. Target (Mean) Encoding
#
# * Replace each category with the mean of the target variable for that category.
#
# * Useful for high-cardinality features (e.g., many city names).
#
# 5. Frequency Encoding
#
# * Replace each category with its frequency (count) in the dataset.
#
# 6. Binary Encoding / Hashing (Advanced)
#
# * Useful for high-cardinality features
#
# * More compact than one-hot encoding

# %% [markdown]
# 14. What is the role of interaction terms in Multiple Linear Regression
#
# * Interaction terms in multiple linear regression are used to model the combined effect of two or more variables on the dependent variable — beyond their individual (main) effects.
#
# * Why Use Interaction Terms?
#
# "Does the effect of one predictor variable depend on the level of another predictor?"
#
# * Example (No Interaction) :
#
#   Let’s say you’re modeling sales based on advertising spend and season :
#
#       Sales = 𝛽0 + 𝛽1(Advertising) + 𝛽2(Season) + 𝜀
#
#   This assumes that the impact of advertising is the same in all seasons.
#
# *  Example (With Interaction Term) :
#
#   Now, include the interaction:
#
#         Sales = 𝛽0 + 𝛽1(Advertising) + 𝛽2(Season) + 𝛽3(Advertising × Season) + 𝜀
#
#   Now, the effect of advertising depends on the season. For example, it might be more effective in winter than in summer.

# %% [markdown]
# 15. How can the interpretation of intercept differ between Simple and Multiple Linear Regression
#
# * Simple vs. Multiple Linear Regression
#
# 1. Simple Linear Regression (SLR)
#
#   * Equation :
#
#         𝑌=𝑚𝑋+𝑐
#
#   * Intercept (c) :
#
#      The value of 𝑌 when 𝑋 = 0
#
#   * Interpretation :
#
#      “If the independent variable 𝑋 is 0, then the predicted value of 𝑌 is 𝑐.”
#
#   *  Example :
#
#      If you're predicting house price based on square footage:
#
#      𝑐 = 50,000
#
#      Interpretation : "When square footage = 0, the predicted house price is $50,000."
#
# 2. Multiple Linear Regression (MLR)
#
#   * Equation:
#
#         𝑌 = 𝛽0 + 𝛽1𝑋1 + 𝛽2𝑋2 + ⋯ + 𝛽𝑛𝑋𝑛
#
#   * Intercept (𝛽0) :
#
#      The predicted value of 𝑌 when all independent variables 𝑋1, 𝑋2, ..., 𝑋𝑛 are zero.
#
#   * Interpretation:
#
#      “If all predictors are 0, then the predicted value of 𝑌 is 𝛽0.”
#
#   *  Example :
#
#      If you're predicting salary based on education (years) and experience (years) :
#
#      𝛽0 = 25,000
#
#      Interpretation : "If both education and experience = 0, the model predicts a salary of $25,000."
#
# * In SLR, the intercept has a clear, direct meaning.
#
# * In MLR, the intercept is more abstract, and may not represent a realistic scenario.

# %% [markdown]
# 16. What is the significance of the slope in regression analysis, and how does it affect predictions
#
# * The slope (also called a regression coefficient) is one of the most important elements in both Simple and Multiple Linear Regression. It quantifies the relationship between an independent variable and the dependent variable.
#
# * In Simple Linear Regression:
#
#   * Equation :
#
#      Y=mX+c
#   * Slope (m):
#
#      Represents the change in the predicted value of 𝑌 for a one-unit increase in 𝑋.
#
#   * Interpretation:
#
#      “For each additional unit of 𝑋, 𝑌 increases (or decreases) by 𝑚 units, assuming all else constant.”
#
# * In Multiple Linear Regression:
#
#   * Equation:
#
#      𝑌 = 𝛽0 + 𝛽1𝑋1 + 𝛽2𝑋2 + ⋯ + 𝛽𝑛𝑋𝑛
#
#   * Each slope 𝛽𝑖 represents the effect of 𝑋𝑖 on 𝑌, holding all other variables constant.
#
# * How It Affects Predictions :
#
#   * Positive Slope : 𝑌 increases as 𝑋 increases.
#
#   * Negative Slope : 𝑌 decreases as 𝑋 increases.
#
#   * Zero Slope : No relationship between 𝑋 and 𝑌.
#
# * In prediction :
#
#      Predicted 𝑌 = Intercept + (Slope × Input 𝑋)
#
# * The slope directly determines how steeply or strongly predictions change with 𝑋.

# %% [markdown]
# 17.  How does the intercept in a regression model provide context for the relationship between variables.
#
# * The intercept in a regression model is the point where the regression line (or plane, in multiple regression) crosses the Y-axis — it's the predicted value of the dependent variable (Y) when all independent variables (X’s) are equal to zero.
#
# 1. In Simple Linear Regression
#
#    Equation : 𝑌 = 𝑚𝑋 + 𝑐
#
#  * Intercept (c) :
#
#    The predicted value of 𝑌 when 𝑋 = 0.
#
#  * Example :
#
#      If you're predicting a house price based on square footage :
#
#      𝑐 = 50,000 “When square footage = 0, the predicted price is $50,000.”
#
# 2. In Multiple Linear Regression
#
#      Equation : 𝑌 = 𝛽0 + 𝛽1𝑋1 + 𝛽2𝑋2 + ⋯ + 𝛽𝑛𝑋𝑛
#
#  * Intercept (𝛽0) :
#
#      The predicted value of 𝑌 when all 𝑋𝑖 = 0.
#
#  *  Example :
#
#    If you're predicting income based on:
#
#    education (years)
#
#    experience (years)
#
#    Then : 𝛽0 = 20,000 → "A person with 0 education and 0 experience is predicted to earn $20,000."
#
# * If zero isn't a realistic value for your predictors (e.g., age = 0), the intercept may not have a practical meaning, but it still supports the model structure.

# %% [markdown]
# 18.  What are the limitations of using R² as a sole measure of model performance.
#
# * The coefficient of determination (R²) measures how well your independent variables explain the variability of the dependent variable.
#
#   While it’s useful, relying on R² alone can be misleading.
#
#   Ranges from 0 to 1 (or 0% to 100%)
#
#   Higher R² ⇒ more variance in the target variable is explained by the model
#
# * Why You Shouldn’t Rely Solely on R²:
#
# 1. Does Not Indicate Model Accuracy
#
#   * A high R² doesn’t mean predictions are close to actual values.
#
#   * It measures fit, not error.
#
# 2. Does Not Detect Overfitting
#
#   * R² always increases when you add more variables — even if they're irrelevant.
#
#   * This can give a false sense of improvement.
#
# 3. Not Comparable Across Different Datasets
#
#   * R² is dataset-specific.
#
#   * You can’t compare R² from different models on different datasets.
#
# 4.  Assumes Linearity
#
#   * R² assumes a linear relationship.
#
#   * If your data has non-linear trends, R² may be low even for a good model.
#
# 5.  Insensitive to Bias
#
#   * R² doesn’t reveal if your model consistently overpredicts or underpredicts.

# %% [markdown]
# 19. How would you interpret a large standard error for a regression coefficient.
#
# * The standard error (SE) of a regression coefficient tells you how precisely that coefficient is estimated. A large standard error means there is high uncertainty about the true value of the coefficient.
#
# * If a coefficient has a large SE, then:
#
#    * The coefficient estimate is unstable or noisy
#
#    * Small changes in the data could lead to big swings in the estimated value
#
#    * The variable may not be a reliable predictor

# %% [markdown]
# 20. How can heteroscedasticity be identified in residual plots, and why is it important to address it.
#
# * Heteroscedasticity occurs when the variance of residuals (errors) is not constant across all levels of the independent variables.
#
# * In contrast, homoscedasticity means residuals have equal variance — which is a key assumption of linear regression.
#
# * How to Identify Heteroscedasticity Using Residual Plots
#
# Plot :
#
#   X-axis: Predicted values (or independent variable)
#
#   Y-axis: Residuals (actual − predicted)
#
# * Example :
#
#   * If residuals fan out as predictions increase (e.g., cone or megaphone shape), that’s a classic sign of heteroscedasticity.
#
# * Why Is It Important to Address?
#
#   1. Violates regression assumptions
#
#    * Leads to biased or inefficient standard errors
#
#    * Affects confidence intervals and hypothesis tests
#
#   2. Inaccurate p-values
#
#    * You might incorrectly determine a variable is significant (Type I or II errors)
#
#   3. Reduced model trustworthiness
#
#    * Predictions may still be unbiased, but statistical inference becomes unreliable

# %% [markdown]
# 21. What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R².
#
# * If a Multiple Linear Regression model has a high R² but a low Adjusted R², it suggests a problem with irrelevant or excessive predictors in your model.
#
# * R² always increases (or stays the same) when you add more independent variables, even if they don't help.
#
# * Adjusted R² decreases if the added variable does not improve the model enough to justify its inclusion.
#
# * Interpretation :
#
#      A high R² but low Adjusted R² means your model might look good superficially, but it likely includes predictors that aren’t actually useful.
#
# * Example :
#
#   Let’s say:
#
#      * R² = 0.85
#
#      * Adjusted R² = 0.55
#
# This implies:
#
#   * 85% of the variation in the target seems to be explained.
#
#   * But after accounting for how many predictors were used, only 55% is reliably explained.

# %% [markdown]
# 22. Why is it important to scale variables in Multiple Linear Regression.
#
# While scaling (standardizing or normalizing) variables isn't always strictly required for Multiple Linear Regression, it often improves the model's performance and interpretability, especially in specific contexts.
#
# 1. Ensures Fair Comparison of Coefficients
#
# In raw form :
#
# * Predictors measured on different scales (e.g., income in thousands vs. age in years) can skew the coefficient sizes.
#
# Scaling allows you to :
#
#   * Compare the importance of features directly
#
#   * Interpret coefficients in standardized units
#
# 2. Improves Numerical Stability
#
# * Features with very large or very small values can cause numerical issues when computing the regression solution (matrix inversion).
#
# 3. Essential for Regularized Models
#
# If you're using:
#
#   * Ridge Regression (L2)
#
#   * Lasso Regression (L1)
#
#   * Elastic Net
#
# then scaling is critical.
#
#   * These models apply penalties to the coefficients, and unscaled features.
#
# 4. Makes Gradient Descent More Efficient
#
# If you're using iterative optimization (like in Stochastic Gradient Descent), scaling :
#
# * Leads to faster convergence.

# %% [markdown]
# 23. What is polynomial regression.
#
# * Polynomial Regression is a type of linear regression where the relationship between the independent variable(s) and the dependent variable is modeled as an nth-degree polynomial.
#
# *  The Equation :
#
#   Instead of a straight line (as in simple linear regression), it fits a curve:
#
#      𝑦 = 𝛽0 + 𝛽1𝑥 + 𝛽2𝑥2 + 𝛽3𝑥3 + ⋯ + 𝛽𝑛𝑥𝑛 + 𝜀
#
#   y: Target variable
#
#   𝑥 : Independent variable
#
#   𝛽𝑖 : Coefficients
#
#   𝑛 : Degree of the polynomial
#
#   𝜀 : Error term
#
# * It transforms the input variables by raising them to powers, allowing the model to fit non-linear trends.
#
# * Despite the curve, it’s still a linear model because it's linear in the coefficients 𝛽.

# %% [markdown]
# 24. How does polynomial regression differ from linear regression.
#
# Though both are forms of regression, they model the relationship between variables differently:
#
# 1. Modeling Shape of the Relationship
#
#   Aspect        -  Linear Regression    -     Polynomial Regression
#
#   Relationship  -  Straight-line        -     Curved (non-linear)
#
#   Equation      -  𝑦 = 𝛽0+𝛽1𝑥           -     𝑦 = 𝛽0+𝛽1𝑥+𝛽2𝑥2+…
#
#   Type of fit	  -  Linear trend	        -    Non-linear trend
#
# 2. Feature Transformation
#
#   * Linear Regression uses raw features (e.g., 𝑥)
#
#   * Polynomial Regression uses powers of features (e.g., 𝑥,𝑥2,𝑥3) as additional predictors.
#
# 3. Still Linear in Parameters
#
#   * Despite the curve in polynomial regression, it is still a linear model in terms of its coefficients.
#
#   * It's called “polynomial” due to the input transformation,not the parameter behavior.
#
# 4. Risk of Overfitting
#
#   * Risk Level	   ----       Description
#   * Linear	       ----      Low — too simple for complex data
#   * Polynomial	   ----       High (especially with high-degree polynomials)

# %% [markdown]
# 25. When is polynomial regression used.
#
# * Polynomial Regression is used when the relationship between the independent variable(s) and the dependent variable is non-linear, but can still be modeled as a smooth curve.
#
# *  Common Scenarios Where Polynomial Regression Is Useful:
#
# 1. Non-linear trends
# 2. Quadratic/cubic relationships
# 3. Diminishing returns
# 4. Growth modeling
# 5. Physics & natural sciences
# 6. Engineering
# 7. Medical data
#
# * Example :
#
#   1. Economics :
#
#      Modeling profit vs. price, where profits rise to a point and then fall.
#
#   2. Agriculture :
#
#      Crop yield vs. fertilizer amount – too little or too much reduces yield.
#
#   3. Marketing :
#
#      Sales vs. ad spend – shows saturation beyond a certain spend level.

# %% [markdown]
# 26. What is the general equation for polynomial regression.
#
# * General Equation for Polynomial Regression
#
#   The general form of a polynomial regression equation of degree 𝑛 is:
#
#      𝑦 = 𝛽0 + 𝛽1𝑥 + 𝛽2𝑥2 + 𝛽3𝑥3 + ⋯ + 𝛽𝑛𝑥𝑛 + 𝜀
#
#   y   --  	Dependent (target) variable
#
#   x --	Independent variable
#
#   x2,x3,…,xn -- Polynomial terms (nonlinear in input)
#
#   β0 --  Intercept (constant term)
#
#   β1,β2,…,βn  --  Coefficients for each term
#
#   ε   --  	Error term (residual)

# %% [markdown]
# 27. Can polynomial regression be applied to multiple variables.
#
# *  Yes — Polynomial Regression Can Be Applied to Multiple Variables.
#
# This is called Multivariate Polynomial Regression, and it models non-linear relationships between multiple independent variables and a dependent variable by including :
#
#   * Powers of each variable (e.g., 𝑥12,𝑥23)
#
#   * Interaction terms (e.g., 𝑥1𝑥2)
#
# * Use Cases :
#
#   * Modeling real-world systems with non-linear interactions (e.g., physics, biology, finance)
#
#   * Capturing curved surfaces or boundaries in multivariate data.

# %% [markdown]
# 28. What are the limitations of polynomial regression.
#
# While polynomial regression is a powerful tool for modeling non-linear relationships, it comes with several important limitations that should be carefully considered :
#
# 1. Overfitting (High Variance)
#
#   * As the degree of the polynomial increases, the model becomes more flexible — but this can lead to overfitting.
#
#   * The model may fit the training data too closely, capturing noise instead of the actual trend.
#
# 2. Extrapolation is Unreliable
#
#   * Polynomial regression is very unstable outside the range of the training data.
#
#   * Predictions for 𝑥 values far beyond the training range can be wildly inaccurate, especially for higher degrees.
#
# 3. Multicollinearity
#
#   * Adding polynomial and interaction terms can introduce high correlation among features (e.g., 𝑥, 𝑥2, 𝑥3).
#
#   * This makes coefficient estimates unstable and hard to interpret.
#
# 4. Increased Complexity
#
#   * More terms mean more parameters to estimate, increasing computational cost.
#
#   * High-degree models can be hard to interpret, especially with multiple variables.
#
# 5. Sensitive to Outliers
#
#   * Outliers can have a disproportionate influence on the fitted curve, especially in high-degree models.
#
# 6. Harder to Select the Right Degree
#
#   * There is no fixed rule for choosing the best polynomial degree.
#
#   * Requires model selection techniques like:
#
#     * Cross-validation
#
#     * Adjusted R²
#
#     * AIC/BIC

# %% [markdown]
# 29. What methods can be used to evaluate model fit when selecting the degree of a polynomial.
#
# Choosing the right degree for a polynomial regression model is crucial — too low and you underfit, too high and you overfit.
#
# Here are the most effective methods to help you evaluate model performance and select the best degree :
#
# 1. Cross-Validation (CV)  Most Recommended
#
#   * Split data into training/validation folds (e.g., 5-fold or 10-fold)
#
#   * Train polynomial models of different degrees
#
#   * Compare average validation error across folds
#
#   Use metrics like:
#
#     * Mean Squared Error (MSE)
#
#     * Root Mean Squared Error (RMSE)
#
# 2. Adjusted R²
#
#   * Unlike regular R², this metric penalizes model complexity.
#
#   * It increases only if adding a new term improves the model more than expected by chance.
#
#   ![image.png](data:image/png;base64,...)
#
#   Where :
#
#   𝑛 : number of observations
#
#   𝑝 : number of predictors (including polynomial terms)
#
# 3. AIC / BIC (Akaike/Bayesian Information Criterion)
#
#   * Penalize models for extra parameters.
#
#   * Lower values = better model fit with simpler complexity.
#
#   * AIC	Good for prediction
#
#   * BIC	Harsher penalty; better for model simplicity
#
# 4. Residual Plots
#
#   * Check for patterns in residuals:
#
#     * If residuals form a curve, you're underfitting (degree too low).
#
#     * If residuals look randomly scattered, fit is likely appropriate.
#
#     * Large swings? You might be overfitting.
#
# 5. Hold-out Validation Set
#
#   * Manually split data (e.g., 70% train, 30% test)
#
#   * Compare test error for different degrees
#
#   * Works best with enough data.

# %% [markdown]
# 30. Why is visualization important in polynomial regression.
#
# * Visualization plays a critical role in polynomial regression because it helps you understand, evaluate, and communicate how well your model is capturing the underlying patterns in the data — especially when those patterns are non-linear.
#
# * Key Reasons Why Visualization Matters :
#
# 1. Detecting Underfitting or Overfitting
#
#   * A linear fit may miss curves (underfitting).
#
#   * A high-degree polynomial might wiggle too much (overfitting).
#
# 2. Understanding the Model’s Behavior
#
#   * Polynomial regression introduces curvature in predictions.
#
#   * Plots help you interpret :
#
#     * Where the curve bends
#
#     * Whether the trend makes sense
#
#     * How extreme predictions behave (especially at the edges)
#
# 3. Checking for Extrapolation Risks
#
#   * Polynomial models often behave unpredictably outside the data range.
#
#   * Visuals help spot unrealistic spikes or dips at the edges of the curve.
#
# 4. Validating Residuals and Errors
#
#   * Residual plots help check whether errors are :
#
#     * Randomly distributed (good)
#
#     * Showing patterns (bad — possibly underfitting or misspecification)
#
# 5. Choosing the Right Degree
#
#   * Plotting models of different degrees side-by-side makes it easy to :
#
#     * Spot the best-fitting curve
#
#     * Avoid unnecessary complexity

# %% [markdown]
# 31. How is polynomial regression implemented in Python?
#
# You can implement polynomial regression easily using scikit-learn.
#
# Here's a complete walkthrough :
#
# 1. Import Required Libraries :
#
#      import numpy as np
#
#      import matplotlib.pyplot as plt
#
#      from sklearn.linear_model import LinearRegression
#
#      from sklearn.preprocessing import PolynomialFeatures
#
#      from sklearn.pipeline import make_pipeline
#
# 2. Prepare the Data :
#
#      Example: 1D feature
#
#      X = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
#
#      y = np.array([3, 6, 9, 15, 20, 28, 39])
#
# 3. Create and Train a Polynomial Regression Model :
#
#      Create a pipeline: PolynomialFeatures + LinearRegression
#
#      degree = 2    # You can change this to 3, 4, etc.
#
#      model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
#
#      model.fit(X, y)
#
# 4. Make Predictions and Plot the Results :
#
#      Generate predictions
#
#      X_test = np.linspace(0, 8, 100).reshape(-1, 1)
#
#      y_pred = model.predict(X_test)
#
#      Plot
#
#      plt.scatter(X, y, color='blue', label='Data')
#
#      plt.plot(X_test, y_pred, color='red', label=f'Degree {degree} Fit')
#
#      plt.xlabel('X')
#
#      plt.ylabel('y')
#
#      plt.title('Polynomial Regression')
#
#      plt.legend()
#
#      plt.grid(True)
#
#      plt.show()
#
# 5. Bonus : Check Model Performance
#
#      from sklearn.metrics import mean_squared_error, r2_score
#
#      y_train_pred = model.predict(X)
#
#      print("R² score:", r2_score(y, y_train_pred))
#
#      print("MSE:", mean_squared_error(y, y_train_pred))
#
# 6. If You Have Multiple Features :
#
#      X can be a DataFrame or NumPy array with multiple columns
#
#      from sklearn.model_selection import train_test_split
#
#      Split your dataset
#
#      X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
#      Fit polynomial regression
#
#      poly_model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
#
#      poly_model.fit(X_train, y_train)
